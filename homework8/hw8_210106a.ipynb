# %% [markdown]
# <a href="https://colab.research.google.com/github/lbuerger/IANNwTF/blob/main/homework8/hw8_210106a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import time

# %%
# load data and only use the 'train' part of it
load = tf.keras.datasets.fashion_mnist.load_data()
print("train images",load[0][0].shape)
print("train labels",load[0][1].shape)
print("test images",load[1][0].shape)
print("test labels",load[1][1].shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# train images (60000, 28, 28)
# train labels (60000,)
# test images (10000, 28, 28)
# test labels (10000,)

# %%
# plot the first entries to get an idea of the data
fig = plt.figure(figsize=(10,10))
class_names={0:'shirt/top',1:'trouser', 2:'pullover', 3:'dress', 4:'coat', 5:'sandal', 6:'shirt', 7:'sneaker',8:'bag', 9:'boot'}
for i in range(1,37):
  img = load[0][0][i]
  fig.add_subplot(6,6,i)
  
  plt.imshow(img, cmap="gray_r")
  plt.axis('off')  
  # the label is 0 if the image contains malaria and 1 if it does not
  plt.title( str(class_names[int(load[0][1][i])]))

fig.show()

# %%
def preprocess_img(image):
  """
  normalize between -1 and 1
  """
  
  max = tf.math.reduce_max(image)
  min = tf.math.reduce_min(image)
  image = ((image - min) / (max - min) -0.5) *2
  image = tf.reshape(image,image.shape + (1,))
  image = tf.image.resize(image,[32,32])
  return image

# %%
# Train dataset
ds_train_img = tf.data.Dataset.from_tensor_slices(load[0][0])
ds_train_img = ds_train_img.map(lambda img: preprocess_img(img))
ds_train_label = tf.data.Dataset.from_tensor_slices(load[0][1])
for entry in ds_train_label:
  print(entry)
  break;
#ds_train_label = ds_train_label.map(lambda label: tf.one_hot(label, 10))
ds_train_label = ds_train_label.map(lambda label: (1,))
for entry in ds_train_label:
  print(entry)
  break;
ds_train = tf.data.Dataset.zip((ds_train_img, ds_train_label))
#ds_train = ds_train.batch(64).shuffle(buffer_size=64)

# test dataset
"""
ds_tst_img = tf.data.Dataset.from_tensor_slices(load[1][0])
ds_tst_img = ds_tst_img.map(lambda img: preprocess_img(img))
ds_tst_label = tf.data.Dataset.from_tensor_slices(load[1][1])
ds_tst_label = ds_tst_label.map(lambda label: tf.one_hot(label, 10))
ds_tst = tf.data.Dataset.zip((ds_tst_img, ds_tst_label))
#ds_tst = ds_tst.batch(64).shuffle(buffer_size=64)
"""
print(ds_train)
#print(ds_tst)
# Out:
# tf.Tensor(9, shape=(), dtype=uint8)
# (<tf.Tensor: shape=(), dtype=int32, numpy=1>,)
# <ZipDataset shapes: ((32, 32, 1), ((),)), types: (tf.float32, (tf.int32,))>

# %%
for entry in ds_train:
  print(entry[1])
  break;
# Out:
# (<tf.Tensor: shape=(), dtype=int32, numpy=1>,)

# %%
# re-plot the first nine entries after the mapping
def one_hot_to_int(one_hot):
  """
  reverse one hot function returning the int to the one hot vector
  """
  count = 0
  for entry in one_hot:
    if entry:
      break
    count += 1
  return count

count = 0
fig = plt.figure(figsize=(10,10))
#class_names={0:'airplane',1:'automobile', 2:'bird', 3:'cat', 4:'deer', 5:'dog', 6:'frog', 7:'horse',8:'ship', 9:'truck'}
for img in ds_train:
  count += 1
  fig.add_subplot(6,6,count)
  #print(img[0].numpy()[:,:,0])
  plt.imshow(img[0][:,:,0]/2+0.5, cmap="gray_r")
  plt.axis('off')
  #plt.title(class_names[one_hot_to_int(img[1])])
  
  if count == 36:
    break;
fig.show()

# %%
# perf batching, shuffeling and prefetching
train_ds = ds_train.batch(32).shuffle(buffer_size=64).prefetch(4)
#test_ds = ds_tst.batch(64).shuffle(buffer_size=64).prefetch(4)

# %%
# to check the shape (here: 32 batch size and a 32x32 image with 3 colours)
for (img,label) in train_ds:
    print("image",img.shape)
    print("max",tf.reduce_max(img).numpy(), "min", tf.reduce_min(img).numpy(), "mean", tf.reduce_mean(img).numpy())
    #print(img[0,:,:,0])
    #print("label",label.shape)
    break;
# Out:
# image (32, 32, 32, 1)
# max 0.9955576 min -1.0 mean -0.40393823

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Layer
from tensorflow.keras import layers

class Discriminator(Model):
  def __init__(self):
    super(Discriminator, self).__init__()
    
    minmax = tf.keras.constraints.MinMaxNorm(min_value=-0.01,max_value=0.01)
    self.layer_list = [
      # 28x28x1
      layers.Conv2D(32, kernel_size = 3, activation = None, padding ='same', input_shape=(32,32,1), kernel_constraint=minmax),
      #layers.BatchNormalization(),
      layers.Activation(tf.nn.leaky_relu),
      #layers.MaxPool2D(pool_size=(2,2)),
      layers.Conv2D(2, kernel_size = 3, strides=2, activation = None, padding = 'same' ),
      layers.BatchNormalization(),
      layers.Activation(tf.nn.leaky_relu),
      # 14x14xN
      layers.Conv2D(64, kernel_size = 3, activation = None, padding ='same', kernel_constraint=minmax),
      layers.BatchNormalization(),
      layers.Activation(tf.nn.leaky_relu),
      #layers.MaxPool2D(pool_size=(2,2)),
      layers.Conv2D(4, kernel_size = 3, strides=2, activation = None, padding = 'same' ),
      layers.BatchNormalization(),
      layers.Activation(tf.nn.leaky_relu),
      # 7x7xN 
      layers.Conv2D(128, kernel_size = 3, activation = None, padding ='same', kernel_constraint=minmax),
      layers.BatchNormalization(),
      layers.Activation(tf.nn.leaky_relu),
      #layers.MaxPool2D(pool_size=(2,2)),
      layers.Conv2D(8, kernel_size = 3, strides=2, activation = None, padding = 'same' ),
      layers.BatchNormalization(),
      layers.Activation(tf.nn.leaky_relu),
      # 4x4xN
      layers.Conv2D(256, kernel_size = 3, activation = None, padding ='same', kernel_constraint=minmax),
      layers.BatchNormalization(),
      layers.Activation(tf.nn.leaky_relu),
      #layers.MaxPool2D(pool_size=(2,2)),
      layers.Conv2D(16, kernel_size = 3, strides=2, activation = None, padding = 'same' ),
      layers.BatchNormalization(),
      layers.Activation(tf.nn.leaky_relu),
      # 2x2xN 
      layers.Conv2D(512, kernel_size = 3, strides=2, activation = None, padding ='same'),
      layers.BatchNormalization(),
      layers.Activation(tf.nn.leaky_relu),
      # 1x1xN
      
      layers.GlobalAveragePooling2D(),
      # N
      layers.Dense(1, activation="sigmoid")
    ]

  def call(self, x):
      for layer in self.layer_list:
        x = layer(x)
      return x

class Generator(Model):
  def __init__(self, space_size):
    super(Generator, self).__init__()
    #print("Embedding size:", shape)
    self.layer_list = [
      layers.Dense(16*256, activation="linear", input_shape=((space_size,))),
      layers.Reshape((4,4,256)),
      layers.Conv2DTranspose(128,5,strides=2,activation=None,padding='same'),
      layers.BatchNormalization(),
      layers.Activation(tf.nn.relu),
      #layers.Conv2D(64, 3, activation = None, padding ='same'),
      #layers.BatchNormalization(),
      #layers.Activation(tf.nn.relu),
      layers.Conv2DTranspose(64,5,strides=2,activation=None,padding='same'),
      layers.BatchNormalization(),
      layers.Activation(tf.nn.relu),
      #layers.Conv2D(64, 3, activation = None, padding ='same'),
      #layers.BatchNormalization(),
      #layers.Activation(tf.nn.relu),
      layers.Conv2DTranspose(32,5,strides=2,activation=None,padding='same'),
      layers.BatchNormalization(),
      layers.Activation(tf.nn.relu),
      #layers.Conv2D(64, 3, activation = None, padding ='same'),
      #layers.BatchNormalization(),
      #layers.Activation(tf.nn.relu),
      layers.Conv2D(1,kernel_size=1,activation="tanh",padding="same")

    ]
  def call(self, x):
      for layer in self.layer_list:
        x = layer(x)
      return x

# %%
x = tf.ones((32,32,32,1))
print(x.shape)
disc = Discriminator()
y = disc(x)
print(y.shape)
gen = Generator(100)
rng = (tf.random.normal((32,100)))
print(rng.shape)
z = gen(rng)
print(z.shape)
#print(z[0,:,:,0])
#z[0,:,:,0]
#plt.imshow(z[0,:,:,0])
#print(y)
# Out:
# (32, 32, 32, 1)
# (32, 1)
# (32, 100)
# (32, 32, 32, 1)

# %%
def random_input(batches, space_size):
  #distr = tf.random.normal((batches, space_size),stddev=1)
  #distr = tf.clip_by_value(distr,-3,3)
  distr = tf.random.uniform((batches, space_size))
  return distr

def train_generator(generator, discriminator, space_size, loss_function, optimizer):
  # loss_object and optimizer_object are instances of respective tensorflow classes
  with tf.GradientTape() as tape:
    generated_images = generator(random_input(32,space_size))
    result = discriminator(generated_images)
    loss = loss_function(tf.ones_like(result), result) #wants to fool the discriminator
    #loss = -tf.math.reduce_sum(result)
    #gradients = tape.gradient(loss, generator.trainable_variables)
  #optimizer.apply_gradients(zip(gradients, generator.trainable_variables))
  optimizer.minimize(loss,generator.trainable_variables, tape=tape)
  best_image = generated_images[tf.argmax(result)[0],:,:,0]
  acc = tf.reduce_mean(tf.clip_by_value(result,0,1))
  #acc = tf.reduce_max(result)
  return loss,  best_image, acc

def train_discriminator(generator, discriminator, space_size, input, loss_function, optimizer, pre_train=False):
  # loss_object and optimizer_object are instances of respective tensorflow classes
  with tf.GradientTape() as tape:
    generated_images = generator(random_input(32,space_size))
    #if pre_train:
    #  generated_images = - tf.ones_like(generated_images)
    #images = tf.concat([generated_images,input],0)
    #generated_batch_size = generated_images.shape[0]
    #input_batch_size = input.shape[0]
    result_fake = discriminator(generated_images)
    result_real = discriminator(input)
    #print(tf.math.reduce_mean(result_fake).numpy(), tf.math.reduce_mean(result_real).numpy()) 
    loss = loss_function(tf.ones((input_batch_size),1),result_real) + loss_function(tf.zeros((generated_batch_size,1)),result_fake)
    #loss =   tf.math.reduce_sum(result_fake) - tf.math.reduce_sum(result_real) 
    #gradients = tape.gradient(loss, discriminator.trainable_variables)
  #optimizer.apply_gradients(zip(gradients, discriminator.trainable_variables))
  optimizer.minimize(loss,discriminator.trainable_variables, tape=tape)
  acc = 1 - tf.reduce_mean(tf.clip_by_value(result_fake,0,1))
  #acc = (tf.reduce_mean(result_real) - tf.reduce_mean(result_fake)) / (tf.reduce_mean(tf.abs(result_real)) + tf.reduce_mean(tf.abs(result_fake)))
  return loss, acc 
  
def train_step(generator, discriminator, space_size, input, loss_function, optimizer):
  # loss_object and optimizer_object are instances of respective tensorflow classes  
  with tf.GradientTape(persistent=True) as tape:
    generated_images = generator(random_input(32,space_size))
    #images = tf.concat([generated_images,input],0)
    generated_batch_size = generated_images.shape[0]
    input_batch_size = input.shape[0]
    #labels = tf.concat([tf.zeros((generated_batch_size,1)),tf.ones((input_batch_size,1))],0)
    result_fake = discriminator(generated_images)
    result_real = discriminator(input)
    #print(labels, result)
    loss_gen = loss_function(tf.ones_like(result_fake), result_fake)
    loss_disc = loss_function(tf.ones((input_batch_size),1),result_real) + loss_function(tf.zeros((generated_batch_size,1)),result_fake)

  gradients_gen = tape.gradient(loss_gen, generator.trainable_variables)

  gradients_disc = tape.gradient(loss_disc, discriminator.trainable_variables)
  optimizer.apply_gradients(zip(gradients_gen, generator.trainable_variables))
  optimizer.apply_gradients(zip(gradients_disc, discriminator.trainable_variables))
  best_image = generated_images[tf.argmax(result_fake)[0],:,:,0]
  return loss_gen, loss_disc, best_image

# %%
temp = random_input(1,196)
temp = tf.reshape(temp,[14,14])
plt.imshow(temp)
plt.show()

# %%
#train_step()
space_size = 10
generator = Generator(space_size)
discriminator = Discriminator()

# Using binary correntropy due to values between 0 and 1
loss_function = tf.keras.losses.BinaryCrossentropy()
# Using the Adam optimizer with the defined learnig rate
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, amsgrad=True)
input = tf.ones((32,28,28,1))
# loss_object and optimizer_object are instances of respective tensorflow classes  
with tf.GradientTape(persistent=True) as tape:
  generated_images = generator(random_input(32,space_size))
  #images = tf.concat([generated_images,input],0)
  generated_batch_size = generated_images.shape[0]
  input_batch_size = input.shape[0]
  #labels = tf.concat([tf.zeros((generated_batch_size,1)),tf.ones((input_batch_size,1))],0)
  result_fake = discriminator(generated_images)
  result_real = discriminator(input)
  #print(labels, result)
  loss_gen = loss_function(tf.ones_like(result_fake), result_fake)
  loss_disc = loss_function(tf.ones((input_batch_size),1),result_real) + loss_function(tf.zeros((generated_batch_size,1)),result_fake)

gradients_gen = tape.gradient(loss_gen, generator.trainable_variables)

gradients_disc = tape.gradient(loss_disc, discriminator.trainable_variables)
optimizer.apply_gradients(zip(gradients_gen, generator.trainable_variables))
optimizer.apply_gradients(zip(gradients_disc, discriminator.trainable_variables))
best_image = generated_images[tf.argmax(result_fake)[0],:,:,0]
#return loss_gen, loss_disc, best_image

# %%
tf.keras.backend.clear_session()

### Hyperparameters
num_epochs = 100
learning_rate = 0.0001
running_average_factor = 0.95

# Initialize the model.
#model = DenseNet(growth_rate=4, bottleneck=False)
#model = ResNet()
space_size = 100
generator = Generator(space_size)
discriminator = Discriminator()

# Using binary correntropy due to values between 0 and 1
cross_entropy_loss = tf.keras.losses.BinaryCrossentropy()
# Using the Adam optimizer with the defined learnig rate
optimizer_gen = tf.keras.optimizers.Adam(learning_rate=learning_rate,amsgrad=True)
optimizer_disc = tf.keras.optimizers.Adam(learning_rate=0.0002,amsgrad=True)

# Initialize lists for later visualization.
train_losses_gen = []
train_losses_disc = []
#test_losses = []
#test_accuracies = []

#testing once before we begin
#test_loss, test_accuracy = test(model, test_ds, cross_entropy_loss)
#test_losses.append(test_loss)
#test_accuracies.append(test_accuracy)
for data in train_ds:
  discriminator(data[0])
  break
print(discriminator.summary())
generator(random_input(32,space_size))
print(generator.summary())
#print("Pre-learning")
#print('test loss:', round(test_loss,4), 'acc:', round(test_accuracy,6))

#check how model performs on train data once before we begin
#train_loss, _ = test(model, train_ds, cross_entropy_loss)
#train_losses.append(train_loss)

# We train for num_epochs epochs.
time0 = time.time()
"""
running_average_disc = 0
#print(len(train_ds))

#pre train discriminator on empty image
count = 0 
while running_average_disc > 0.2 or count < 20:
    count+=1
    #print(input.shape)
    #break
      
    train_loss_disc = train_discriminator(generator,discriminator, space_size, input, cross_entropy_loss, optimizer, pre_train=True)
    running_average_disc = running_average_factor * running_average_disc  + (1 - running_average_factor) * train_loss_disc
print('Pretraining discriminator against blank images loss:', round(running_average_disc.numpy(),4))
"""
training_max = 20
for epoch in range(num_epochs):
    print('Epoch: __ ' + str(epoch))
    #time1 = time.time()
    train_ds = train_ds.shuffle(buffer_size=32)
    #test_ds = test_ds.shuffle(buffer_size=128)

    #training (and checking in with training)
    running_average_gen = 0
    running_average_disc = 0
    running_acc_gen = 0
    running_acc_disc = 0
    
    # train discriminator
    count = 0
    for (input,_) in train_ds:
        count+=1
        #print(input.shape)
        #break
         
        train_loss_disc, acc_disc = train_discriminator(generator,discriminator, space_size, input, cross_entropy_loss, optimizer_disc)
        running_acc_disc = 0.95 * running_acc_disc + (1-0.95) * acc_disc
        running_average_disc = running_average_factor * running_average_disc  + (1 - running_average_factor) * train_loss_disc
        #if (count> 00 and running_acc_disc > 0.7 ):
        #  break
        #if (count > training_max):
        #  training_max *= 2
        #  break
    print('train_loss_disc:', round(running_average_disc.numpy(),4), "disc_acc:",round(running_acc_disc.numpy(),4),"after",count)

    # train generator
    count = 0
    #for i in range(len(train_ds)):
    acc_gen = 0.0
    while running_acc_gen < 0.9 or count < 499:
        count+=1
        train_loss_gen, output_gen, acc_gen = train_generator(generator, discriminator, space_size, cross_entropy_loss, optimizer_gen)
        running_acc_gen = 0.95 * running_acc_gen + (1-0.95) * acc_gen
        running_average_gen = running_average_factor * running_average_gen  + (1 - running_average_factor) * train_loss_gen
        if count%500 == 0: #(count > 20 and running_average_gen<0.05) or
          fig, ax = plt.subplots(1,2)
          ax[0].imshow(tf.clip_by_value(output_gen,-1,1)/2+0.5, cmap="gray_r")
          ax[0].axis('off')
          ax[1].hist(tf.reshape(output_gen,(1,-1)))
          plt.title("Generator acc "+str(round(running_acc_gen.numpy(),4))+" avg "+str(tf.reduce_mean(output_gen).numpy()))
          plt.show()
          #first=False
          #if running_average_gen < 0.05:
          #  break
        #print("count",count,"training_max",training_max)
        if  count > 2000: #or count > training_max*2 :
          break
    fig, ax = plt.subplots(1,2)
    ax[0].imshow(tf.clip_by_value(output_gen,-1,1), cmap="gray_r")
    ax[0].axis('off')
    ax[1].hist(tf.reshape(output_gen,(1,-1)))
    plt.title("Generator acc "+str(round(running_acc_gen.numpy(),4))+" avg "+str(tf.reduce_mean(output_gen).numpy()))
    plt.show()
    print("gen_acc",round(running_acc_gen.numpy(),4),"after",count)
    train_losses_gen.append(running_average_gen)
    train_losses_disc.append(running_average_disc)
    #print(running_average_gen,running_average_disc)


    #testing
    #test_loss, test_accuracy = test(model, test_ds, cross_entropy_loss)
    #test_losses.append(test_loss)
    #test_accuracies.append(test_accuracy)
    run_time = time.time()-time0 
    print("After Epoch",epoch,'train_loss_gen:', round(running_average_gen.numpy(),4), 'train_loss_disc:', round(running_average_disc.numpy(),4), "running:",round(run_time,1),"sec ETA:",round(((run_time)/(epoch+1)*num_epochs-run_time)/60,1),"min")
# Out:
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            multiple                  320
# _________________________________________________________________
# activation_3 (Activation)    multiple                  0
# _________________________________________________________________
# conv2d_2 (Conv2D)            multiple                  578
# _________________________________________________________________
# batch_normalization_3 (Batch multiple                  8
# _________________________________________________________________
# activation_4 (Activation)    multiple                  0
# _________________________________________________________________
# conv2d_3 (Conv2D)            multiple                  1216
# _________________________________________________________________
# batch_normalization_4 (Batch multiple                  256
# _________________________________________________________________
# activation_5 (Activation)    multiple                  0
# _________________________________________________________________
# conv2d_4 (Conv2D)            multiple                  2308
# _________________________________________________________________
# batch_normalization_5 (Batch multiple                  16
# _________________________________________________________________
# activation_6 (Activation)    multiple                  0
# _________________________________________________________________
# conv2d_5 (Conv2D)            multiple                  4736
# _________________________________________________________________
# batch_normalization_6 (Batch multiple                  512
# _________________________________________________________________
# activation_7 (Activation)    multiple                  0
# _________________________________________________________________
# conv2d_6 (Conv2D)            multiple                  9224
# _________________________________________________________________
# batch_normalization_7 (Batch multiple                  32
# _________________________________________________________________
# activation_8 (Activation)    multiple                  0
# _________________________________________________________________
# conv2d_7 (Conv2D)            multiple                  18688
# _________________________________________________________________
# batch_normalization_8 (Batch multiple                  1024
# _________________________________________________________________
# activation_9 (Activation)    multiple                  0
# _________________________________________________________________
# conv2d_8 (Conv2D)            multiple                  36880
# _________________________________________________________________
# batch_normalization_9 (Batch multiple                  64
# _________________________________________________________________
# activation_10 (Activation)   multiple                  0
# _________________________________________________________________
# conv2d_9 (Conv2D)            multiple                  74240
# _________________________________________________________________
# batch_normalization_10 (Batc multiple                  2048
# _________________________________________________________________
# activation_11 (Activation)   multiple                  0
# _________________________________________________________________
# global_average_pooling2d (Gl multiple                  0
# _________________________________________________________________
# dense_1 (Dense)              multiple                  513
# =================================================================
# Total params: 152,663
# Trainable params: 150,683
# Non-trainable params: 1,980
# _________________________________________________________________
# None
# Model: "generator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                multiple                  413696
# _________________________________________________________________
# reshape (Reshape)            multiple                  0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran multiple                  819328
# _________________________________________________________________
# batch_normalization (BatchNo multiple                  512
# _________________________________________________________________
# activation (Activation)      multiple                  0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr multiple                  204864
# _________________________________________________________________
# batch_normalization_1 (Batch multiple                  256
# _________________________________________________________________
# activation_1 (Activation)    multiple                  0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr multiple                  51232
# _________________________________________________________________
# batch_normalization_2 (Batch multiple                  128
# _________________________________________________________________
# activation_2 (Activation)    multiple                  0
# _________________________________________________________________
# conv2d (Conv2D)              multiple                  33
# =================================================================
# Total params: 1,490,049
# Trainable params: 1,489,601
# Non-trainable params: 448
# _________________________________________________________________
# None
# Epoch: __ 0
# train_loss_disc: 0.0235 disc_acc: 0.9926 after 1875
# gen_acc 1.0 after 499
# After Epoch 0 train_loss_gen: 0.0 train_loss_disc: 0.0235 running: 118.2 sec ETA: 195.0 min
# Epoch: __ 1
# train_loss_disc: 1.3861 disc_acc: 0.5 after 1875
# gen_acc 0.5 after 2001
# After Epoch 1 train_loss_gen: 0.6931 train_loss_disc: 1.3861 running: 278.8 sec ETA: 227.7 min
# Epoch: __ 2
# train_loss_disc: 1.3854 disc_acc: 0.4995 after 1875
# gen_acc 0.5004 after 2001
# After Epoch 2 train_loss_gen: 0.6923 train_loss_disc: 1.3854 running: 436.8 sec ETA: 235.4 min
# Epoch: __ 3
# train_loss_disc: 0.0053 disc_acc: 0.997 after 1875
# gen_acc 1.0 after 499
# After Epoch 3 train_loss_gen: 0.0 train_loss_disc: 0.0053 running: 554.0 sec ETA: 221.6 min
# Epoch: __ 4
# train_loss_disc: 0.0096 disc_acc: 0.9956 after 1875
# gen_acc 1.0 after 499
# After Epoch 4 train_loss_gen: 0.0 train_loss_disc: 0.0096 running: 670.9 sec ETA: 212.4 min
# Epoch: __ 5
# train_loss_disc: 0.0009 disc_acc: 0.9994 after 1875
# gen_acc 1.0 after 499
# After Epoch 5 train_loss_gen: 0.0 train_loss_disc: 0.0009 running: 787.4 sec ETA: 205.6 min
# Epoch: __ 6
# train_loss_disc: 0.0011 disc_acc: 0.9993 after 1875
# gen_acc 1.0 after 499
# After Epoch 6 train_loss_gen: 0.0 train_loss_disc: 0.0011 running: 904.4 sec ETA: 200.3 min
# Epoch: __ 7
# train_loss_disc: 0.0039 disc_acc: 0.9985 after 1875
# gen_acc 0.9994 after 499
# After Epoch 7 train_loss_gen: 0.0006 train_loss_disc: 0.0039 running: 1021.7 sec ETA: 195.8 min
# Epoch: __ 8
# train_loss_disc: 0.0023 disc_acc: 0.9986 after 1875
# gen_acc 1.0 after 499
# After Epoch 8 train_loss_gen: 0.0 train_loss_disc: 0.0023 running: 1137.7 sec ETA: 191.7 min
# Epoch: __ 9
# train_loss_disc: 0.0011 disc_acc: 0.9996 after 1875
# gen_acc 0.9998 after 499
# After Epoch 9 train_loss_gen: 0.0002 train_loss_disc: 0.0011 running: 1253.9 sec ETA: 188.1 min
# Epoch: __ 10
# train_loss_disc: 0.0009 disc_acc: 0.9996 after 1875
# gen_acc 1.0 after 499
# After Epoch 10 train_loss_gen: 0.0 train_loss_disc: 0.0009 running: 1369.4 sec ETA: 184.7 min
# Epoch: __ 11
# train_loss_disc: 0.0008 disc_acc: 0.9995 after 1875
# gen_acc 0.9999 after 499
# After Epoch 11 train_loss_gen: 1e-04 train_loss_disc: 0.0008 running: 1484.8 sec ETA: 181.5 min
# Epoch: __ 12
# train_loss_disc: 0.0016 disc_acc: 0.9995 after 1875
# gen_acc 0.9998 after 499
# After Epoch 12 train_loss_gen: 0.0002 train_loss_disc: 0.0016 running: 1599.6 sec ETA: 178.4 min
# Epoch: __ 13
# train_loss_disc: 0.0045 disc_acc: 0.9981 after 1875
# gen_acc 0.9996 after 499
# After Epoch 13 train_loss_gen: 0.0004 train_loss_disc: 0.0045 running: 1713.6 sec ETA: 175.4 min
# Epoch: __ 14
# train_loss_disc: 0.0021 disc_acc: 0.9993 after 1875
# gen_acc 0.9999 after 499
# After Epoch 14 train_loss_gen: 1e-04 train_loss_disc: 0.0021 running: 1827.5 sec ETA: 172.6 min
# Epoch: __ 15
# train_loss_disc: 0.0027 disc_acc: 0.999 after 1875
# gen_acc 0.9984 after 499
# After Epoch 15 train_loss_gen: 0.0016 train_loss_disc: 0.0027 running: 1940.6 sec ETA: 169.8 min
# Epoch: __ 16
# train_loss_disc: 0.002 disc_acc: 0.9991 after 1875
# gen_acc 0.9996 after 499
# After Epoch 16 train_loss_gen: 0.0004 train_loss_disc: 0.002 running: 2054.3 sec ETA: 167.2 min
# Epoch: __ 17
# train_loss_disc: 0.0009 disc_acc: 0.9996 after 1875
# gen_acc 0.9999 after 499
# After Epoch 17 train_loss_gen: 1e-04 train_loss_disc: 0.0009 running: 2168.4 sec ETA: 164.6 min
# Epoch: __ 18
# train_loss_disc: 0.0006 disc_acc: 0.9997 after 1875
# gen_acc 1.0 after 499
# After Epoch 18 train_loss_gen: 0.0 train_loss_disc: 0.0006 running: 2282.2 sec ETA: 162.2 min
# Epoch: __ 19
# train_loss_disc: 0.0022 disc_acc: 0.9995 after 1875
# gen_acc 0.9991 after 499
# After Epoch 19 train_loss_gen: 0.0009 train_loss_disc: 0.0022 running: 2395.7 sec ETA: 159.7 min
# Epoch: __ 20
# train_loss_disc: 0.0094 disc_acc: 0.997 after 1875
# gen_acc 0.9963 after 499
# After Epoch 20 train_loss_gen: 0.0037 train_loss_disc: 0.0094 running: 2509.6 sec ETA: 157.3 min
# Epoch: __ 21
# train_loss_disc: 0.0018 disc_acc: 0.9994 after 1875
# gen_acc 0.9984 after 499
# After Epoch 21 train_loss_gen: 0.0016 train_loss_disc: 0.0018 running: 2622.8 sec ETA: 155.0 min
# Epoch: __ 22
# train_loss_disc: 0.0055 disc_acc: 0.9984 after 1875
# gen_acc 0.9997 after 499
# After Epoch 22 train_loss_gen: 0.0003 train_loss_disc: 0.0055 running: 2736.9 sec ETA: 152.7 min
# Epoch: __ 23
# train_loss_disc: 0.0072 disc_acc: 0.9987 after 1875
# gen_acc 0.9996 after 499
# After Epoch 23 train_loss_gen: 0.0004 train_loss_disc: 0.0072 running: 2851.0 sec ETA: 150.5 min
# Epoch: __ 24
# train_loss_disc: 0.007 disc_acc: 0.9988 after 1875
# gen_acc 0.9963 after 499
# After Epoch 24 train_loss_gen: 0.0037 train_loss_disc: 0.007 running: 2964.9 sec ETA: 148.2 min
# Epoch: __ 25
# train_loss_disc: 0.0023 disc_acc: 0.9994 after 1875
# gen_acc 0.9999 after 499
# After Epoch 25 train_loss_gen: 1e-04 train_loss_disc: 0.0023 running: 3080.1 sec ETA: 146.1 min
# Epoch: __ 26
# train_loss_disc: 0.0015 disc_acc: 0.9996 after 1875
# gen_acc 0.9949 after 499
# After Epoch 26 train_loss_gen: 0.0051 train_loss_disc: 0.0015 running: 3195.2 sec ETA: 144.0 min
# Epoch: __ 27
# train_loss_disc: 0.0035 disc_acc: 0.9992 after 1875
# gen_acc 1.0 after 499
# After Epoch 27 train_loss_gen: 0.0 train_loss_disc: 0.0035 running: 3309.2 sec ETA: 141.8 min
# Epoch: __ 28
# train_loss_disc: 0.0008 disc_acc: 0.9998 after 1875
# gen_acc 0.9896 after 499
# After Epoch 28 train_loss_gen: 0.0104 train_loss_disc: 0.0008 running: 3424.5 sec ETA: 139.7 min
# Epoch: __ 29
# train_loss_disc: 0.0005 disc_acc: 0.9999 after 1875
# gen_acc 0.9993 after 499
# After Epoch 29 train_loss_gen: 0.0007 train_loss_disc: 0.0005 running: 3539.2 sec ETA: 137.6 min
# Epoch: __ 30
# train_loss_disc: 0.0036 disc_acc: 0.9987 after 1875
# gen_acc 0.9985 after 499
# After Epoch 30 train_loss_gen: 0.0015 train_loss_disc: 0.0036 running: 3654.1 sec ETA: 135.6 min
# Epoch: __ 31
# train_loss_disc: 0.0008 disc_acc: 0.9996 after 1875
# gen_acc 0.9977 after 499
# After Epoch 31 train_loss_gen: 0.0023 train_loss_disc: 0.0008 running: 3769.7 sec ETA: 133.5 min
# Epoch: __ 32
# train_loss_disc: 0.0027 disc_acc: 0.9993 after 1875
# gen_acc 0.9965 after 499
# After Epoch 32 train_loss_gen: 0.0035 train_loss_disc: 0.0027 running: 3885.7 sec ETA: 131.5 min
# Epoch: __ 33
# train_loss_disc: 0.0012 disc_acc: 0.9996 after 1875
# gen_acc 0.9986 after 499
# After Epoch 33 train_loss_gen: 0.0014 train_loss_disc: 0.0012 running: 4002.2 sec ETA: 129.5 min
# Epoch: __ 34
# train_loss_disc: 0.001 disc_acc: 0.9998 after 1875
# gen_acc 0.9955 after 499
# After Epoch 34 train_loss_gen: 0.0045 train_loss_disc: 0.001 running: 4117.6 sec ETA: 127.4 min
# Epoch: __ 35
# train_loss_disc: 0.0027 disc_acc: 0.9991 after 1875
# gen_acc 0.9897 after 499
# After Epoch 35 train_loss_gen: 0.0104 train_loss_disc: 0.0027 running: 4233.1 sec ETA: 125.4 min
# Epoch: __ 36
# train_loss_disc: 0.0129 disc_acc: 0.9969 after 1875
# gen_acc 0.9941 after 499
# After Epoch 36 train_loss_gen: 0.0059 train_loss_disc: 0.0129 running: 4347.6 sec ETA: 123.4 min
# Epoch: __ 37
# train_loss_disc: 0.0066 disc_acc: 0.9978 after 1875
# gen_acc 0.991 after 499
# After Epoch 37 train_loss_gen: 0.009 train_loss_disc: 0.0066 running: 4462.3 sec ETA: 121.3 min
# Epoch: __ 38
# train_loss_disc: 0.0069 disc_acc: 0.9978 after 1875
# gen_acc 0.9878 after 499
# After Epoch 38 train_loss_gen: 0.0123 train_loss_disc: 0.0069 running: 4576.9 sec ETA: 119.3 min
# Epoch: __ 39
# train_loss_disc: 0.0 disc_acc: 1.0 after 1875
# gen_acc 0.9996 after 499
# After Epoch 39 train_loss_gen: 0.0004 train_loss_disc: 0.0 running: 4690.6 sec ETA: 117.3 min
# Epoch: __ 40
# train_loss_disc: 0.0008 disc_acc: 0.9995 after 1875
# gen_acc 0.9991 after 499
# After Epoch 40 train_loss_gen: 0.0009 train_loss_disc: 0.0008 running: 4804.6 sec ETA: 115.2 min
# Epoch: __ 41
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-ea91fe2cedb7> in <module>()
#      79         #break
#      80
# ---> 81         train_loss_disc, acc_disc = train_discriminator(generator,discriminator, space_size, input, cross_entropy_loss, optimizer_disc)
#      82         running_acc_disc = 0.95 * running_acc_disc + (1-0.95) * acc_disc
#      83         running_average_disc = running_average_factor * running_average_disc  + (1 - running_average_factor) * train_loss_disc
#
# <ipython-input-13-9cab4d1cf5e4> in train_discriminator(generator, discriminator, space_size, input, loss_function, optimizer, pre_train)
#      36     #gradients = tape.gradient(loss, discriminator.trainable_variables)
#      37   #optimizer.apply_gradients(zip(gradients, discriminator.trainable_variables))
# ---> 38   optimizer.minimize(loss,discriminator.trainable_variables, tape=tape)
#      39   acc = 1 - tf.reduce_mean(tf.clip_by_value(result_fake,0,1))
#      40   #acc = (tf.reduce_mean(result_real) - tf.reduce_mean(result_fake)) / (tf.reduce_mean(tf.abs(result_real)) + tf.reduce_mean(tf.abs(result_fake)))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in minimize(self, loss, var_list, grad_loss, name, tape)
#     495     """
#     496     grads_and_vars = self._compute_gradients(
# --> 497         loss, var_list=var_list, grad_loss=grad_loss, tape=tape)
#     498     return self.apply_gradients(grads_and_vars, name=name)
#     499
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in _compute_gradients(self, loss, var_list, grad_loss, tape)
#     546     var_list = nest.flatten(var_list)
#     547     with ops.name_scope_v2(self._name + "/gradients"):
# --> 548       grads_and_vars = self._get_gradients(tape, loss, var_list, grad_loss)
#     549
#     550     self._assert_valid_dtypes([
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in _get_gradients(self, tape, loss, var_list, grad_loss)
#     439   def _get_gradients(self, tape, loss, var_list, grad_loss=None):
#     440     """Called in `minimize` to compute gradients from loss."""
# --> 441     grads = tape.gradient(loss, var_list, grad_loss)
#     442     return list(zip(grads, var_list))
#     443
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1084         output_gradients=output_gradients,
#    1085         sources_raw=flat_sources_raw,
# -> 1086         unconnected_gradients=unconnected_gradients)
#    1087
#    1088     if not self._persistent:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      75       output_gradients,
#      76       sources_raw,
# ---> 77       compat.as_str(unconnected_gradients.value))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/backprop.py in _zeros(shape, dtype)
#     673     return None
#     674
# --> 675   ctx = context.context()
#     676   if not ctx.executing_eagerly():
#     677     return array_ops.zeros(shape, dtype)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/context.py in context_safe()
#    1847
#    1848
# -> 1849 def context_safe():
#    1850   """Returns current context (or None if one hasn't been initialized)."""
#    1851   return _context
#
# KeyboardInterrupt:

# %%
# Visualize accuracy and loss for training and test data. 
# One plot training and test loss.
# One plot training and test accuracy.
plt.figure()
line1, = plt.plot(train_losses_gen,label="generator")
line2, = plt.plot(train_losses_disc,label="discriminator")
plt.xlabel("Training steps")
plt.ylabel("Loss")
plt.legend()
plt.show()
